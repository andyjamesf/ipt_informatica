# %% [markdown]
# <a href="https://www.python.org/">![python24.png](data:image/png;base64,...)
# </a>
# <font color=#C8C8C8 size=6>
# Introdução à programação e Resolução de Problemas
# <a href="http://algorithmi.ipt.pt/"> ![algorithmi24.png](data:image/png;base64,...)</a>

# %% [markdown]
# #Frequência 1 - IPRP - 2024-25

# %% [markdown]
# ## Exercicio 1
# Construa um programa que converta euros para dólares e libras. O programa deve solicitar as taxas de câmbio e o valor em euros.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# taxa de câmbio
# US dolar 	: 1.185
# GBP Libra 	: 0.838
# Valor em euros 	: 12.37
#
# Valor em US Dólar 	= 14.65845
#
# Valor em GBP Libra 	= 10.36606

# %% [markdown]
# ## Exercício 2 – 1,5 valores
# A distância (d) alcançada por um projétil dependem da velocidade inicial (v0) e do ângulo de elevação da arma (θ). Na fórmula a velocidade (v0) está em metros/segundo, a distância (d) em metros, o ângulo (θ)  em radianos e g representa a constante gravítica que vale 9.8. Sabendo que a velocidade inicial (v0) fornecida pela pólvora é 700 Km/h, construa um algoritmo que solicite ao utilizador a distância do alvo em quilómetros (km) e de seguida informe o utilizador qual o ângulo da arma, em graus, de forma a atingir o alvo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# Distância (km) :3
# Angulo =  25.52067793605806

# %% [markdown]
# ## Exercício 3 – 1,5 valores
# Construa um algoritmo que imprima na consola se uma loja está aberta ou fechada. A loja está aberta desde as 8:45:00 até ás 17:30:00.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercício 4 – 1,5 valores
# Construa um algoritmo que solicite ao utilizador o número de pessoas do um grupo e o respetivo peso e de seguida imprima o peso da mais magra.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# Nº de pessoas: 1
# Peso : 10
# Mais magra: 10.0

# %% [markdown]
# ## Exercício 5 – 1,5 valores
# Construa um algoritmo que imprima a figura seguinte. O utilizador deve introduzir a altura do triângulo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# Altura :5
# ....*
# ...**
# ..***
# .****
# *****

# %% [markdown]
# ## Exercício 6 – 3 valores
# a ) Construa uma função que verifique se um número é primo.
#
# b) Utilizando a função anterior construa um programa que calcule todos os números primos com 4 dígitos que começam e terminam com 3.

# %%
# Out:
# 3023 3083 3163 3203 3253 3313 3323 3343 3373 3413 3433 3463 3533 3583 3593 3613 3623 3643 3673 3733 3793 3803 3823 3833 3853 3863 3923 3943

# %% [markdown]
# ## Exercício 7 – 2,5 valores
# Construa um programa que solicite ao utilizador os parâmetros da função f e de seguida imprima o seu resultado.
# MOD – resto da divisão inteira

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# a = 100
# n = 200
# m = 3
# 1

# %% [markdown]
# ## Exercício 8 – 2,5 valores
# Construa um programa que solicite ao utilizador o número de termos da fórmula e de seguida calcule o valor de Nepper através da fórmula da figura.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# Termos : 100
# 2.7182818284590455

# %% [markdown]
# ## Exercício 9 – 2,5 valores
# Construa um programa que solicite ao utilizador o número de termos da fórmula e de seguida calcule a imprima o valor de PI através da fórmula da figura.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# Termos = 100
# 3.141592653589794

# %% [markdown]
# ## Exercício 10 – 2,5 valores
# Construa um programa que solicite ao utilizador o número de termos da fórmula e de seguida calcule a imprima o valor de PI através da fórmula da figura.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# Termos : 100
# 3.141543152314772
