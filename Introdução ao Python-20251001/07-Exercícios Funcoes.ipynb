# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##  **Área e perímetro da Elipse**
#
# Construa um algoritmo que calcule a área e o perímetro de uma elipse.
#
# Escreva as funções:
# - areaElipse
# - perimetroElipse
#
# ![folder[1].jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##**Área e perímetro do losango**
#
# Um losango é uma figura geométrica om os lados todos iguais.
# Contrua um algoritmo para calcular a área e o perímetro de um losango.
# O utilizador deve introduzir o valor das duas diagonais A-C e B-D.
#
# Escreva as funções
# - areaLosango
# - perimetroLosango
#
# ![folder[1].jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##**Área Rosa**
#
# Construa um algoritmo para calcular a área rosa da figura.
# O utilizador deve introduzir as coordenadas do canto inferior esquerdo (x1,y1) e do canto superior direito (x2,y2)
# ![folder[1].jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **números de fibonacci**
#
# Contrua um programa que imprima na consola os primeiros 100 números de fibonacci utilizando a fórmula seguinte
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <a href="http://algorithmi.ipt.pt/">![python24.png](data:image/png;base64,...)</a>
# <font color=#C8C8C8 size=1>
# (c) António Manso - Instituto Politécnico de Tomar   - All rights reserved
# <a href="http://algorithmi.ipt.pt/"> ![algorithmi24.png](data:image/png;base64,...)</a>

# %%
import this
