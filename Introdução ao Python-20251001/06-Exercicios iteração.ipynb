# %% [markdown]
# <a href="https://www.python.org/">![python24.png](data:image/png;base64,...)
# </a>
# <font color=#C8C8C8 size=6>
# Introdução à programação e Resolução de Problemas
# <a href="http://algorithmi.ipt.pt/"> ![algorithmi24.png](data:image/png;base64,...)</a>

# %% [markdown]
# ##Tabuada do 5
# Escreva um algoritmo que imprima na consola a tabuada do 5

# %%
# Out:
# 1  x  5  =  5
# 2  x  5  =  10
# 3  x  5  =  15
# 4  x  5  =  20
# 5  x  5  =  25
# 6  x  5  =  30
# 7  x  5  =  35
# 8  x  5  =  40
# 9  x  5  =  45
# 10  x  5  =  50

# %% [markdown]
# ## Todas as tabuadas
# Escreva um algoritmo que imprima as tabuadas do 1 ao 9

# %% [markdown]
# # Exercício **Divisores de um número**
#
# Construa um algoritmo que escreva na consola os divisores de um número introduzido pelo utilizador.
#
# ![folder[1].jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ```
# # Isto está formatado como código
# ```
#
# #Números Primos
#
# Construa um programa que solicite ao utilizador um número e de seguida diga se o número é "Primo" ou "Comum"
#
# ![folder[1].jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Exercício **Número perfeito**
#
# Um número perfeito é aquele que a soma dos seus divisores é igual a ele próprio
#
# - 6 = 1 + 2 + 3 (perfeito)
# - 28 = 1 + 2 + 4 + 7 + 14 (perfeito)
#
# Construa um algoritmo que solicite a introdução de um número e de seguida diga se ele é "Perfeito" ou normal.
#
# ![numero-perfeito[1].png](data:image/png;base64,...)

# %% [markdown]
# # Exercício **Máximo divisor comum**
#
# Programe um algoritmo que solicite ao utilizador dois numeros e de seguida imprima a máximo divisor comum.
#
# [wikipedia](https://pt.wikipedia.org/wiki/M%C3%A1ximo_divisor_comum)
#
# ![folder[1].jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bom trabalho :-)

# %% [markdown]
# <a href="http://algorithmi.ipt.pt/">![python24.png](data:image/png;base64,...)</a>
# <font color=#C8C8C8 size=1>
# (c) António Manso - Instituto Politécnico de Tomar   - All rights reserved
# <a href="http://algorithmi.ipt.pt/"> ![algorithmi24.png](data:image/png;base64,...)</a>

# %%
print("Flat is better than nested.")
