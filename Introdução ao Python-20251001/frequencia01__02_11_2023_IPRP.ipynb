# %% [markdown]
# ![py.png](data:image/png;base64,...)
# <font size=5  color="#009933">Introdução à programação e Resolução de Problemas
# ![ipt.png](data:image/png;base64,...)

# %% [markdown]
# #Frequência 1 - Algoritmos 2023 - 2024
#
# Frequencia de  [Introdução à programação e Resolução de Problemas](https://portal2.ipt.pt/pt/Cursos/licenciaturas/l_-_ei/911931/) da [Licenciatura em Engenharia Informática](https://portal2.ipt.pt/pt/cursos/Licenciaturas/L_-_EI/) do [Instituto Politécnico de tomar](https://www.ipt.pt/)

# %% [markdown]
# ##Exercício 1
# Construa um programa para calcular a área de uma elipse

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Exercício 2
# Construa um programa para calcular a área preenchida da figura.
# O utilizador deve introduzir as coordenadas do canto inferior esquerdo (x1,y1) e do canto superior direito (x2,y2) e de seguida imprimir a área.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Exercício 3
# A fórmula de Binet permite calcular de forma eficiente os números de Fibonacci. O enésimo termo de fibonacci é dado pela parte inteira do número real calculado pela fórmula.
# *	Programe uma função que calcule o enésimo número de fibonacci pela fórmula de Binet.
# *	Construa um programa que imprima na consola os números de fibonacci utilizando a função anterior. A quantidade de números deve ser introduzida pelo utilizador.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Exercício 4
# A fortaleza de um número mede-se pela média dos seus dígitos.
# <br>[0, 4[ - Fraco
# <br>[4, 7[ - Normal
# <br>[7, 9] – Forte
# <br>
# Construa um programa que solicite ao utilizador um número inteiro e de seguida imprima a média dos seus dígitos e a sua fortaleza.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Exercício 5
# A fórmula seguinte calcula o valor do coseno de um ângulo em radianos.
#
# *	Programe uma função que calcule o valor da fórmula com o nº de termos passado por parâmetro.
# *	Construa um programa que solicite ao utilizador o valor de um ângulo em graus, o número de termos de cálculo, e de seguida imprima o seu coseno utilizando a função definida

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Exercício 6
# Construa um programa que solicite ao utilizador o número de termos da fórmula seguinte e de seguida imprima o valor calculado.
# O programa também deve imprimir o valor da raiz quadrada calculado pela função fornecida pela linguagem (sqrt) e o desvio em relação ao valor calculado pela fórmula

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Exercício 7
#
# * Construa a função inteiro numeroDias(inteiro ano, inteiro mes) que recebe como parâmetros o ano e o mês e devolve o número de dias do mês nesse ano.
# Definição de ano bissexto:
# ** São bissextos todos os anos múltiplos de 400
# ** São bissextos todos os múltiplos de 4, exceto se for múltiplo de 100 mas não de 400
# * Construa um programa que solicite ao utilizador o ano e o mês e de seguida imprima o número de dias desse mês.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Exercício 8
# Utilizando a função definida no exercício anterior, construa um programa que calcule e imprima o dia seguinte ao introduzido pelo utilizador.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <a href="http://algorithmi.ipt.pt/">![python24.png](data:image/png;base64,...)</a>
# <font color=#C8C8C8 size=1>
# (c) António Manso - Instituto Politécnico de Tomar   - All rights reserved
# <a href="http://algorithmi.ipt.pt/"> ![algorithmi24.png](data:image/png;base64,...)</a>

# %%
print("Programming is thinking, not typing")
# Out:
# Programming is thinking, not typing
