# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Somatorios

# %% [markdown]
# ##Número de Euler
# Programe que calcule o valor do somatório.<br>
# o utilizador deve introduzir o número de termos do somatório

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## PI - leibniz
# Construa um algoritmo que calcule o valor de PI atrvés da fórmula de Leibniz. O número de termos da fórmula deve ser introduzido pelo utilizador.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Produtorios

# %% [markdown]
# ##PI - wallis
# Construa um algoritmo que calcule o valor de PI através da fórmula de Wallis. O número de termos da fórmula deve ser introduzido pelo utilizador.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## PI - Viéte
# Contrua um algoritmo que calcule o valor de PI com a fórmula apresentada.
# O utilizador deve introduzir o limite do produtório (n).
#
# https://pt.wikipedia.org/wiki/Fórmula_de_Viète

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Funções por ramos

# %% [markdown]
# ##Factorial
# Construa um programa que calcule o fatorial de um número introduzido pelo utilizador utilizando a fórmula

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Algorimto de euclides
# Construa calcule o máximo divisor comum entre dois números utilizando o algoritmo de euclides recursivo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Potência
# Construa um programa que permita calcular a potência entre dois números inteiros.
# sabendo que:
#
# - powR(a,b) = 1  se b for zero
# - powR(a,b) = a * powR(a,b-1) se b for maior que zero
#
# escreva a funcao
#  inteiro powR(inteiro a, inteiro b)
#
# O utilizador deve introduzir a base e o expoente.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <a href="http://algorithmi.ipt.pt/">![python24.png](data:image/png;base64,...)</a>
# <font color=#C8C8C8 size=1>
# (c) António Manso - Instituto Politécnico de Tomar   - All rights reserved
# <a href="http://algorithmi.ipt.pt/"> ![algorithmi24.png](data:image/png;base64,...)</a>

# %%
import this
