# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Exercicios com ciclo enquanto

# %% [markdown]
# ##Numeros Ímpares num intervalo
# Construa um algoritmo que imprima na consola os números ímpares de um itervalo introduzido pelo utilizador.
#
#
#
# ```
# Limite inferior : 4
# Limite superior : 16
# 5 7 9 11 13 15
# ```

# %% [markdown]
# ##Somar digitos Impares
# Construa um algoritmo que solicite ao utilizador um numero e de seguida imprima soma dos digitos impares
#
#
# ```
# Numero : 1237
# Soma dos dígitos impares = 11
# ```

# %% [markdown]
# ##Média da sequência
# Contrua um algoritmo que solicite ao utilizador uma sequência de números inteiros, que termina por zero.
# O algoritmo deve imprimir a sua soma.
#
#
# ```
# Média de uma sequência terminada por zero
# Número : 10
# Número : 3
# Número : 6
# Número : 0
#
# Média = 4.75
# ```

# %% [markdown]
# ##Divisores de um numero
# Construa um algoritmo que imprima na consola os divisores de um numero.
# O numero deve ser introduzido pelo utilizador.
#
#
# ```
# Numero : 12
# Divisores : 1 2 3 4 6
# ```

# %% [markdown]
# ##Número Perfeito
# Em Matemática, um número perfeito é um número natural para o qual a soma de todos os seus divisores naturais próprios (excluindo ele mesmo) é igual ao próprio número.
#
# Construa um algoritmo que solicite ao utilizador um número e de seguida verifique se ele é perfeito ou comum.
#
# - 6 = 1 + 2 + 3
# - 28 = 1 + 2 + 4 + 7 + 18
#
# https://en.wikipedia.org/wiki/Perfect_number
#
#
#
# ```
# Número : 496
# Divisores = 1 2 4 8 16 31 62 124 248
# Soma = 496
# Número Perfeito
# ```

# %% [markdown]
# ##Número Primo
# Um número inteiro positivo primo é aquele que tem somente dois divisores distintos: o 1 e ele próprio.
#
# Contrua um algoritmo que solicite ao utilizador um número e de seguida diga se ele é primo ou composto.
#
#
#
# https://en.wikipedia.org/wiki/Prime_number
#
#
#
# ```
# Número : 7
# Número Primo
# ```
#
#
# ```
# Número : 14
# Número Composto
# ```

# %% [markdown]
# <a href="http://algorithmi.ipt.pt/">![python24.png](data:image/png;base64,...)</a>
# <font color=#C8C8C8 size=3>
# (c) António Manso - Instituto Politécnico de Tomar   - All rights reserved
# <a href="http://algorithmi.ipt.pt/">![python24.png](data:image/png;base64,...)</a>

# %%
import this
